# %%
import pandas as pd
vac = pd.read_csv("sy2021-2022-school-immunization-data-by-vaccine-excel.csv")
vac.head(10)
# Out:
#                      School District                             School Name  \
# 0                   AIU Exceptional                        Mon Valley School
# 1                   AIU Exceptional                        Pathfinder School
# 2                   AIU Exceptional                           Sunrise School
# 3                  Allegheny Valley                 Acmetonia Primary School
# 4                  Allegheny Valley               Cheswick Christian Academy
# 5                  Allegheny Valley             Springdale Jr/Sr High School
# 6  Archangel Gabriel Catholic School                       Archangel Gabriel
# 7                  Ava Marie Academy  Ave Maria Academy - Mt. Lebanon Campus
# 8                  Avalon Elementary                              Northgate
# 9                         Avonworth              Avonworth Elementary School
#
#                             School Address     City Town      Zip  \
# ...
